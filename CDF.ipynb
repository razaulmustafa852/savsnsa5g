# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
low_nsa = pd.read_csv("logfiles/low-mobility/nsa/all.csv")
low_sa = pd.read_csv("logfiles/low-mobility/sa/all.csv")


low_nsa_qoe = pd.read_csv("logfiles/low-mobility/nsa/qoe.csv")
low_sa_qoe = pd.read_csv("logfiles/low-mobility/sa/qoe.csv")


low_nsa_events = pd.read_csv("logfiles/low-mobility/nsa/events.csv")
low_sa_events = pd.read_csv("logfiles/low-mobility/sa/events.csv")

# %%
indoor_nsa = pd.read_csv("logfiles/Indoor/OP-1/NSA/all.csv")
indoor_sa = pd.read_csv("logfiles/Indoor/OP-1/SA/all.csv")

indoor_nsa_qoe = pd.read_csv("logfiles/Indoor/OP-1/NSA/qoe.csv")
indoor_sa_qoe = pd.read_csv("logfiles/Indoor/OP-1/SA/qoe.csv")

indoor_nsa_events = pd.read_csv("logfiles/Indoor/OP-1/NSA/events.csv")
indoor_sa_events = pd.read_csv("logfiles/Indoor/OP-1/SA/events.csv")

indoor_nsa_op_2 = pd.read_csv("logfiles/Indoor/OP-2/NSA/all.csv")

indoor_nsa_op_2_qoe = pd.read_csv("logfiles/Indoor/OP-2/NSA/qoe.csv")
indoor_nsa_op_2_events = pd.read_csv("logfiles/Indoor/OP-2/NSA/events.csv")

# %%
mobility_nsa = pd.read_csv("logfiles/mobility/nsa/all.csv")
mobility_sa = pd.read_csv("logfiles/mobility/sa/all.csv")

mobility_nsa_qoe = pd.read_csv("logfiles/mobility/nsa/qoe.csv")
mobility_sa_qoe = pd.read_csv("logfiles/mobility/sa/qoe.csv")

mobility_nsa_events = pd.read_csv("logfiles/mobility/nsa/events.csv")
mobility_sa_events = pd.read_csv("logfiles/mobility/sa/events.csv")

# %%
extreme_mob_qoe = pd.read_csv("logfiles/extreme/NSA/qoe.csv")
extreme_mob_events = pd.read_csv("logfiles/extreme/NSA/events.csv")

# %%
#Qual

# %%
sns.kdeplot(
    data=indoor_nsa, x="Qual",
    cumulative=True, common_norm=False, label='Indoor'
)
sns.kdeplot(
    data=low_nsa, x="Qual",
    cumulative=True, common_norm=False,  label='Low Mobility'
)

sns.kdeplot(
    data=mobility_nsa, x="Qual",
    cumulative=True, common_norm=False, label='Moderate Mobility'
)
plt.xlabel('RSRQ')
plt.legend()
plt.tight_layout()
plt.savefig('noms/qual_cmp.pdf')
# Show plot
plt.show()
# plt.ylabel('Loaded Percentage')

# %%
sns.kdeplot(
    data=indoor_nsa, x="Level",
    cumulative=True, common_norm=False, label='Indoor'
)
sns.kdeplot(
    data=low_nsa, x="Level",
    cumulative=True, common_norm=False,  label='Low Mobility'
)

sns.kdeplot(
    data=mobility_nsa, x="Level",
    cumulative=True, common_norm=False, label='Moderate Mobility'
)
plt.xlabel('RSRQ')
plt.legend()
plt.tight_layout()
plt.savefig('noms/level_cmp.pdf')
# Show plot
plt.show()
# plt.ylabel('Loaded Percentage')

# %%
sns.kdeplot(
    data=indoor_nsa, x="SNR",
    cumulative=True, common_norm=False, label='Indoor'
)
sns.kdeplot(
    data=low_nsa, x="SNR",
    cumulative=True, common_norm=False,  label='Low Mobility'
)

sns.kdeplot(
    data=mobility_nsa, x="SNR",
    cumulative=True, common_norm=False, label='Moderate Mobility'
)
plt.xlabel('RSRQ')
plt.legend()
plt.tight_layout()
plt.savefig('noms/snr_cmp.pdf')
# Show plot
plt.show()

# %%
sns.kdeplot(
    data=indoor_nsa, x="SNR",
    cumulative=True, common_norm=False, label='Indoor - NSA'
)
sns.kdeplot(
    data=low_nsa, x="SNR",
    cumulative=True, common_norm=False,  label='Low Mobility - NSA'
)

sns.kdeplot(
    data=mobility_nsa, x="SNR",
    cumulative=True, common_norm=False, label='Moderate Mobility - NSA'
)

sns.kdeplot(
    data=indoor_sa, x="SNR",
    cumulative=True, common_norm=False, label='Indoor - SA',linestyle='--'
)
sns.kdeplot(
    data=low_sa, x="SNR",
    cumulative=True, common_norm=False,  label='Low Mobility - SA', linestyle='--'
)

sns.kdeplot(
    data=mobility_sa, x="SNR",
    cumulative=True, common_norm=False, label='Moderate Mobility - SA',linestyle='--'
)

plt.xlabel('SNR')
plt.legend()
plt.tight_layout()
plt.savefig('noms/snr_nsa_sa.pdf')
# Show plot
plt.show()

# %%
sns.kdeplot(
    data=indoor_nsa, x="Qual",
    cumulative=True, common_norm=False, label='Indoor - NSA'
)
sns.kdeplot(
    data=low_nsa, x="Qual",
    cumulative=True, common_norm=False,  label='Low Mobility - NSA'
)

sns.kdeplot(
    data=mobility_nsa, x="Qual",
    cumulative=True, common_norm=False, label='Moderate Mobility - NSA'
)

sns.kdeplot(
    data=indoor_sa, x="Qual",
    cumulative=True, common_norm=False, label='Indoor - SA',linestyle='--'
)
sns.kdeplot(
    data=low_sa, x="Qual",
    cumulative=True, common_norm=False,  label='Low Mobility - SA', linestyle='--'
)

sns.kdeplot(
    data=mobility_sa, x="Qual",
    cumulative=True, common_norm=False, label='Moderate Mobility - SA',linestyle='--'
)

plt.xlabel('RSRQ')
plt.legend()
plt.tight_layout()
plt.savefig('noms/qual_nsa_sa.pdf')
# Show plot
plt.show()

# %%
sns.kdeplot(
    data=indoor_nsa, x="Level",
    cumulative=True, common_norm=False, label='Indoor - NSA'
)
sns.kdeplot(
    data=low_nsa, x="Level",
    cumulative=True, common_norm=False,  label='Low Mobility - NSA'
)

sns.kdeplot(
    data=mobility_nsa, x="Level",
    cumulative=True, common_norm=False, label='Moderate Mobility - NSA'
)

sns.kdeplot(
    data=indoor_sa, x="Level",
    cumulative=True, common_norm=False, label='Indoor - SA',linestyle='--'
)
sns.kdeplot(
    data=low_sa, x="Level",
    cumulative=True, common_norm=False,  label='Low Mobility - SA', linestyle='--'
)

sns.kdeplot(
    data=mobility_sa, x="Level",
    cumulative=True, common_norm=False, label='Moderate Mobility - SA',linestyle='--'
)

plt.xlabel('RSRP')
plt.legend()
plt.tight_layout()
plt.savefig('noms/level_nsa_sa.pdf')
# Show plot
plt.show()

# %%
# Operator X and Y- COMParison

# %%
sns.kdeplot(
    data=indoor_nsa, x="Level",
    cumulative=True, common_norm=False, label='Indoor - Operator-X'
)
sns.kdeplot(
    data=indoor_nsa_op_2, x="Level",
    cumulative=True, common_norm=False, label='Indoor - Operator-Y'
)
plt.xlabel('RSRP')
plt.legend()
plt.tight_layout()
plt.savefig('noms/level_i_vs_2.pdf')
# Show plot
plt.show()

# %%
sns.kdeplot(
    data=indoor_nsa, x="Qual",
    cumulative=True, common_norm=False, label='Indoor - Operator-X'
)
sns.kdeplot(
    data=indoor_nsa_op_2, x="Qual",
    cumulative=True, common_norm=False, label='Indoor - Operator-Y'
)
plt.xlabel('RSRQ')
plt.legend()
plt.tight_layout()
plt.savefig('noms/qual_i_vs_2.pdf')
# Show plot
plt.show()

# %%
sns.kdeplot(
    data=indoor_nsa, x="SNR",
    cumulative=True, common_norm=False, label='Indoor - Operator-X'
)
sns.kdeplot(
    data=indoor_nsa_op_2, x="SNR",
    cumulative=True, common_norm=False, label='Indoor - Operator-Y'
)
plt.xlabel('SNR')
plt.legend()
plt.tight_layout()
plt.savefig('noms/SNR_i_vs_2.pdf')
# Show plot
plt.show()

# %%
# QoE

# %%
low_nsa_qoe.columns
# Out:
# Index(['Video', 'Quality', 'Video Bytes Downloaded', 'Loaded Percentage',
#        'Eid', 'Date', 'Time'],
#       dtype='object')

# %%
def calculate_category_percentage(df, column_name):
    # Get counts of each category
    category_counts = df[column_name].value_counts()
    
    # Calculate percentages
    category_percentages = (category_counts / len(df)) * 100
    
    # Return percentages
    return category_percentages

# %%
# extreme_mob_events = extreme_mob_events[(extreme_mob_events['Category']!='unstarted') & 
#                                         (extreme_mob_events['Category']!='ended') &(extreme_mob_events['Category']!='paused')
#                                        ]

events = extreme_mob_events[(extreme_mob_events['Category']!='unstarted') & 
                                        (extreme_mob_events['Category']!='ended') &(extreme_mob_events['Category']!='paused')
                                       ]

# %%
#LowSA -

# %%
events.shape
# Out:
# (34, 8)

# %%
events[events['Category']=='buffering'].shape
# Out:
# (17, 8)

# %%
#indoor - 56 NSA Events
#indoor - 11 SA
#low - 3 NSA Events
#low - 15 SA Events
#moderate - 2 NSA Events
#moderate - 13 SA Events
#Extreme NSA - 17

# %%
buf = events[events['Category']=='buffering']
buf
# Out:
#           Video   Quality  Status   TimeStall    Eid        Date      Time  \
# 0   9jrP7460a4o  unknown,       3    0.000000   mcar  2024-06-14  18:45:28
# 3   9jrP7460a4o   medium,       3   59.125147   mcar  2024-06-14  18:46:30
# 6   Baur2Ypgd60  unknown,       3    0.000000  mcar2  2024-06-14  18:51:49
# 10  JMbBjKnUoC4  unknown,       3    0.000000    mc3  2024-06-14  18:56:19
# 14  9ZfN87gSjvI  unknown,       3    0.000000    mc4  2024-06-14  19:13:50
# 18  9jrP7460a4o  unknown,       3    0.000000    mc5  2024-06-14  15:37:08
# 22  oh904_HdkwY  unknown,       3    0.000000    mc6  2024-06-14  15:45:48
# 24  oh904_HdkwY   hd2160,       3   57.534996    mc6  2024-06-14  15:46:48
# 27  oh904_HdkwY    large,       3  157.439753    mc6  2024-06-14  15:47:32
# 30  oh904_HdkwY    large,       3   54.424606    mc6  2024-06-14  15:47:45
# 33  oh904_HdkwY  unknown,       3    0.000000    mc6  2024-06-15   8:54:57
# ...

# %%
category_counts = buf['Eid'].value_counts()
category_counts
# Out:
# Eid
# mc6      5
# mcar     2
# mc9      2
# mcar2    1
# mc3      1
# mc4      1
# mc5      1
# mc7      1
# mc8      1
# mc10     1
# mc12     1
# Name: count, dtype: int64

# %%
def count_category_values(df, column_name):
    # Get the counts of each category
    category_counts = df[column_name].value_counts()
    
    # Calculate the percentages
    category_percentages = (category_counts / len(df)) * 100
    
    # Combine counts and percentages into a new DataFrame
    result = pd.DataFrame({
        'Count': category_counts,
        'Percentage': category_percentages
    })
    
    return result

# %%
category_stats = count_category_values(mobility_sa, 'EVENT')
print(category_stats)
# Out:
#                          Count  Percentage
# EVENT
# PERIODIC                  4208   67.511632
# HANDOVER_DATA_5G5G          74    1.187229
# IRAT_HANDOVER_DATA_4G5G     12    0.192524
# LOG START                   11    0.176480
# LOG_END                     11    0.176480
# IRAT_HANDOVER_DATA_5G4G     11    0.176480
# CELL_RESELECTION_5G5G        7    0.112305
# HANDOVER_DATA_4G4G           3    0.048131

# %%
#Done
